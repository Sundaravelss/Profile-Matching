# %%
fb_friends=['claire chapman @ChappoClaire',
 'Teddy S. Swaray @teddy87_s',
 'Fitzroy 1878 Williams @FitzroyWillia17',
 'DEVILS RED @PatrPt',
 'dynmufc @dyn_mufc',
 'Kavita Trikam @katrikz',
 'R.Essam @Ressy_16',
 'Alan Shields @AlanShields12',
 'BRUNO POGBA VAN DE BEEK @sammyrocks19',
 'North Texas Reds @northtxreds',
 'Kieran Dempsey @dempsek',
 '@sugar~T @mcruffeohthomps',
 'Simon Cragg @SimonCragg6',
 'kavi arasan @kaviarasan_t',
 'Dennis Amakove @DennisAmakove11',
 'Red Devil Bling @lee_bling1878',
 'Andy goucher MUFC @andrewgoucher',
 'Dan @Altgthr',
 'dave jones @taffdon',
 'One Love @abbausmanUK',
 'Tom @Tomlawrence_02',
 'Mr SHERMAN @badian_seydou',
 'Aloice Angasa @AngasaAloice',
 'aliman united @alimanu20',
 'Anthony red devil 82 @Redmachine82',
 'MUFC_RUPERT @RupertUnited',
 'Mediocre club. @propagandaFC',
 'HorseSoul @itss_laiba',
 'Donna @donnamacbabe',
 'Debdeep Sarkar @debdeepsarkards',
 'Pedro @Pedro29910657',
 'YogarajMuthukrishnan @yogaraj1309',
 'FiveCantonas.co.uk @FiveCantonas_',
 'Andrew Norris @NozzaMUFC',
 'Andrew Darwin @AndrewDarwin12',
 'Michael dele @michaeldele10',
 'Ganesh Kumar @Ganesh69818',
 'George Nuttall @GeorgeNuttall5',
 'Stevemufcecfcengland @stevemufcecfc',
 'john abraham @johnpolo26',
 'Rod Arklie @roddyreddevil',
 'Sad, Sweet Gremlin @CostelloC137',
 'Charley Joskis @CJoskis',
 'Luke @DissectMUFC',
 'Felix Ajakaiye @FelixAjakaiye1',
 'Peter Knasinsky @knasinsky',
 'Ashlee White @AshleeW94550666',
 'Colin Aimson @Biffo16',
 'Laura @Laura41504228',
 'Andrew Crichton @Andrew041265',
 'Ryan @RJD_MUFC',
 'Chris Woodhead @ChrisWoodhead88',
 'Malcolm Davies @MalcolmDavies6',
 'William @clovisMUFC',
 'united is my heaven @MR_RED_4_EVER',
 'James Christopher @jameschrist68',
 'Harsh V Singh @Harsh_Voice',
 'eben @pure_sancho7utd',
 'Red Devils Analysis @RedDevilsAna',
 'GlazersOutWoodwardOut @GlazersOutttttt',
 'easy @easyhaq61',
 'MUFCSP @mufcsp',
 'The United Hawk @TheUnitedHawk',
 'Michael Anim @ruud_kagawa',
 'AmericanRedDevils @usareddevils',
 'Abul Pogba @AbulPogba',
 'nickdillon @nickdillonart',
 'Irish Reds ➐ @ManUtdIrishReds',
 'UtdsRedDevils @UtdsDevils68',
 'Guru @ThatEngineCrew',
 'Saurav Roy @IamSauravRoy',
 'Dream Chaser @AsonabaBosompem',
 'lewis @utd_Lewis',
 'Vaidya @Vaidya_becks',
 'Caroline Dovaston @bloom200',
 'Rollo Tomasi @RolloTomaszn',
 'manutd way @Kirubelmanutd1',
 'Ayo.com @Ayomarunga1',
 'Chris Orrin @ChrisOrrin',
 'red darbo @RedDarbo',
 'Iam Semmy young richie @semmy_young',
 'Ian Croombs @IanCroombs1',
 'John Murphy @johnmurphy_mufc',
 'Jay_Aditya_M @Jayadit79119920',
 'ackers @Nitemare70',
 'Jeeves AJ @Ajayjeev',
 'Stuart @Juckylim',
 'SSA @ParteyPooper12',
 'Ian Beister @Real_IanBeister',
 'Pradhan Abhijeet @Gutsybas',
 'mikeeee @mikeeee37199181',
 'Mark @MG_DINGER',
 'The Club Cricketer @TheClubCricket1',
 'Anurag Shukla @akku_meenu',
 'FRED THE RED @ManUnitedGoals2',
 'Sai Vignesh @SVRedDevil',
 'Kurt Galdal @KGaldal',
 'THEO Odogwu @SirChibuikeTheo',
 'Pedro @PeterSeale4',
 'daniel smith #Freedom #20times @daniels21220856',
 'Vagheni Zaïrois @VZairois',
 'Jadon Greenwood @JadonGreenwood',
 'eddie white. @1957eddie',
 'Lincoln Red @KeithMacca10',
 'Paul @pau1luvsutd',
 'Ellie Van Gobin @VanGobin',
 'Red Mentality @RedMentality',
 'Elanchezhiyan @Elan_chezhiyan',
 '𝚂𝚝𝚛𝚎𝚝𝚏𝚘𝚛𝚍 𝚃𝚊𝚕𝚔𝚜 @StretfordTalks',
 'RedUnited20 @RUnited20',
 'LUHG @LUHG39148356',
 'Deepak @DeepakS_10',
 'Paul wilson @mrwils81',
 'L*E*W*I*S @lew2u',
 'valzi @CheoziV',
 'Stephen Hall @StephenHall2009',
 'Kjetil Bjørgen @kbjorgen',
 'Stephen Murr @StephenMurr1',
 'Dean Adams @RedD_mufc',
 'Mike Lord @mikelordcomedy',
 'MUFC75 @MUFC751',
 'No Context Always Sunny @NoContextIASIP_',
 '@RedDevilCL',
 'John Vincent @JohnVin11642461',
 'oyewole sodiq @oyewolesodiq13',
 'Jonathan @JonFosterMUFC',
 'ReggieMurr @murr_reggie',
 'Vignesh R @Vigneshrv94',
 'john graham @spinnerjohn',
 'MUFC Charleston @CharlestonMufc',
 'TheValleyReds @TheValleyReds',
 'Itz_Pjayzy @Itz_Pjayzy',
 'Jor @Jor14711272',
 'Scott Ley @ScottLey3',
 'Pradeep Srinivasan @sjtspradeep',
 'The_Real_Deal @nextleveltruths',
 'Sydney Inglese [Dredgen] @Singlese',
 'John Sinclair @john_nufc42',
 'Myles @MylesDevine',
 'Jordan Ashfield @JAshfield18',
 'Stuart Hepworth @stuhepwo',
 'Padraic Toolan @PadraicToolan',
 'Isaacs @dji1982',
 'IB Omo Bibire @Biomancunian25',
 'Adam Doležálek @Aidam95',
 'James Jamo Taylor @jjamo23',
 'Tɩʆʆaŋʏ & angel @EmpresTiffany1',
 'UtdPaul @JohnPaul_UTD',
 'Lokamar @Lokamar__',
 'The Red Devils @Chris_Lawro_',
 'Mannikanum Maamsu @fire4cannon',
 'Joyce scott @Indinlily',
 'Sajedaa @Sajedaa_F9T',
 'Mr. Frost @rfrost626',
 'jeevanantham @tweetsbyjiiva',
 'David Opoku @DavidOp73679702',
 'am_Alexis @iam_Alexis8',
 'Michael Anos @anos_michael',
 'Kev Bennett @KevinBe45418098',
 'Kev Brown @kevin51283',
 'Trev UTID @knaggsy097',
 'Rob Daly @RobDaly7',
 'William Pan @William31945950',
 'Dena @denacutrone',
 'SALL @JustSallx',
 'mustefa @OmerSheran',
 'Suyambulingam @SuyambulingamJ',
 'hashwin @hashwinjak',
 'MUFC99 @PavRana_7',
 'Georgie-May @GeorgieRastaMay',
 'Oluwashinayomi A. Ayobami @Oluwashinayomi2',
 'DICKY BARTON @DICKYB1970',
 'Tony @Tonydevilsred',
 'Ben @Bred147',
 'vinod @Vinodbalaji7',
 'Sunshine @lineup1978',
 'steve thomaz @ttomtweet',
 'Dr.Red @DrRed31473646',
 '@Karen25276193',
 'Baz Buz @surgeryscar',
 'Martin @martinryan968',
 'Ricki Lee Pepper @PepperRicki',
 '𝙎𝙧𝙞 @Thanda_soru',
 'manutdreligiontour @manutdreligion1',
 'VIGNESH MN @vignesh_mn',
 'James Jackson @Doublejayz72',
 'Ange @AngelliUnited',
 'DaveH69 @Dave_H69',
 'Paul berry @Paulber35907121',
 'DILLINGER @DillanMUFC',
 'Charlie @sheshe_tom',
 'Aleky @MvoiM',
 'Jεnna -乂o @jenn_bbygirl89',
 'surendhar @surendhar17',
 'Denis Mulindwa @dmulindwa72',
 'ゆうな @tkwoqxeemm',
 'Robert robertreeves@oldtrafford.uk @BestLawRobert1',
 '@asyuraswandy @AsyurAswandy',
 'shaun purdy @PurdyShaun',
 'Fenner @shrewpid',
 'Nnamdi Freeman @uch_ikeolis',
 'ᑎᗩIᗪIᗩ ✯ @Mzznob18',
 'Rajesh @Ravarman',
 'Johnnyhalley @Johnnyhalley3',
 'Exec Global Tours @exec_tours',
 'Jarryd @Jarryd18117150',
 'Johnnyred @thegaffer1969',
 'King_Keano @man_utd_since76',
 'Carl Wallace @Carl336699',
 'essexredmufc @essexredmufc',
 'WaZza @WazZzaUtd',
 'Tony Smith @TonySmithsoul',
 'ANDY DAVIDGE @utdandy',
 'Tomás Pinga @TomasPinga',
 'Romeo Makwatse @ROMEOJUV',
 'fatlad @footboxing',
 'nicholas @DrippyAidan18',
 'Rich @Richard7Hill',
 'Johnny Halley @JohnnyHalley2',
 'Benjamin Brazil @bennymufc',
 'BlackWhiteRED @BlackWhiteRED9',
 'wf_splendor @wfsplendor1',
 'Ben Pearce @benpearcetalks',
 'Prashant @AsocialIndian',
 'Binamu UNITED @omarmzee22',
 'MUST Prize Draw @MUST_Prize_Draw',
 'GENERAL Mmuo @GeneralMmuo',
 'Sav @jonmikesav8',
 'nasa @nasa123456',
 'Beakerr404 @BeakerIsGod',
 'Bryan @United_NYY_KCC',
 'Murtala Suleiman @msuleimangusau',
 'G P @G53P3',
 'anil khandare @anilkhandare9',
 'Naveen P Appan @naveen_p_appan',
 "Wes O'Mac @wesleymcf7",
 'Mohamed Rafiudeen @MdRafi_M_',
 'Mani @07mani',
 'Paddyolager @padang136',
 'Andrew Green @k117gre',
 'Paula @pjf13red',
 'Sophie @Sophie_Clare1',
 'New Vision With Common Skills @vision_common',
 'HurricanePanther @PharaohPanther',
 'Iain @widget40',
 'Mason பச்சக்கட்டை ( ) @MadrasRedDevil',
 'Brian Castner @BrianCastner',
 'F @MUFC_FBU',
 'Manchester United Forever @ManUniited4Ever',
 'Nirmal Kumar Chandru @NirmalK_Chandru',
 '. @MUFCHASLAM',
 'Mark Robinson @Mark_MUFC_CH',
 'TheLogicalUnited @jmansharma',
 'Just Man United @Allan7MUFC',
 'MICKS @Micks_MUFC',
 'Manikandan Pandiyan @Manchester_Mani',
 'Stephen Shaw @shawsy88',
 'On De Beek @OnDeBeek',
 'Vignesh Gandhi @iamgvignesh',
 'Corina @dublinsprincess',
 'Redwhitepapi @redwhitepapi93',
 'Wendy Kerfoot @1965Wendy',
 'Michael Barton @mrmichaelbarton',
 'David Agaba Oche @DavidAgaba11',
 'The United Happy Hour @TheUtdHappyHour',
 'LynneG @lynger2000',
 'VAIRAVA SUNDAR @Sundar_tvs',
 'daved73 @daved731',
 'kevinmathews @kevinma75391550',
 'robert kelly asiamah @kelly_asiamah',
 'Love_Claudine25 @Anne25Claudine',
 'ManUTD-Devil-1994 @1994_manutd',
 'Mike @Mike17425825',
 'Bruno Van De Pogba @AndersonMike21',
 'Raja @Raja_Mani3',
 'Ed The Red @EdBateman84',
 'Manchester History @ManchesterHist1',
 'Larry Chester @LarryCh49598510',
 'Mark Foley #GlazersOut @GlazerScumOut',
 'Fiona May @fionamay4471',
 'United 07 @07S_mufc',
 'Pete @PeteMUFC1991',
 'Red_Devil @RetroRed2',
 'Von Lemon @TheJDE',
 'Rick Stewart @RickStewart18',
 'Cosmin Voican @CosminVoican2',
 'Sharon @sharonm48015004',
 'Catherine Roll @CatherineRoll2',
 'Dave Spencer @Davethemanc15',
 'CANTONA 7 @Cant7ona7',
 'SIXTIMES- - @LFC6DXB',
 'Gar @UtdGar',
 'paul i emery @pauliemery',
 'Tim Schubert @T2TMS',
 'ꜱɪʀ ꜰʀᴇᴅ ʙᴏʏᴄᴏᴛᴛ @FredBoycott',
 'Captain Cake @Suthers44',
 'Rich @RedR1985',
 'Nick @rigsby1734',
 'Aekavin Narula @Aekavin7',
 'Up The John @theOGSeffect',
 'SHEM SHADY @TheZohanKe',
 'kings Amas @AmasKings',
 'Rosie Edwards @RosieEdwards15',
 'Joy @joywinvaz',
 'shawn mckinnon @shawnmckinnon',
 'DecReape @decoreape7',
 '864RedDevils @864_RedDevils',
 'martin elliott @martine56198881',
 'John Sprintall @JSprintall',
 'Kevo @mufcaficionado',
 'trafford man utd @traffordmanutd',
 'GLAZERS OUT @GlazersOut19',
 'ftbl_connor #GlazersOut @ftbl_connor',
 'Boopathi Velu @itsme_boopathiv',
 'Nicola @nicsmy',
 'Mohamed Shewaf @mohamed_shewaf',
 'Rash Kelly @RashKelly5',
 'Yahya Marjan Baloch @YahyaBaloch124',
 'Old Trafford 1968 @RetroForever1',
 'Mel Chambers @MelChambers19',
 'David Hibbert @fabdave',
 'Mark @manu1999ole',
 'Simon Gillen @simongillen',
 'SimBoxx @SimBoxx',
 'ωilf #BLM #glazersout @Ucheguccigoo2',
 'Manchester United Belgique-Belgie-Belgium @FMancunians',
 'Ash @ash22united',
 'johnny bryan ( The Red ) @lanfear51',
 'Bruno SZN @akkomufc10',
 '@admititeve',
 'Naresh Kumar @Nareshkumar0608',
 'Isaac Hackman @IsaacHackman11',
 'Ste Bev @stebevan',
 'Ruf @Roof_A_Loof',
 'Kiran Kumar @kiranAMkumar',
 'John Brosnan @johnpbrosnan2',
 'Abul-pogba @AdamuSalisuAda4',
 'david walsh @davidwalsh1956',
 'KingCantona7 @pal_vegard',
 'utd_zeemi @UTD_Zeemi',
 'Peidy7 @Peidy72',
 'Rob Mills @Millsy1030',
 'Robert Thorburn @DagheadThorburn',
 'Rich Moon @Richard51261467',
 'Nicholas Featley @NicholasFeatley',
 'Dale @27dale',
 'Jade MUFC @RedDevil1988',
 'Yash Dev Sekri @YashDevSekri',
 'Karthick Raja @im_KarthickRaja',
 'Adrian Mitchell @StuartA1958',
 'K @klkxox',
 'Josse Luis Flores @jlsanjurf',
 'Nick Coleman @jubbytub',
 'Ali King @taranakali',
 'O carte @ocarte_net',
 'Manchester United @ManutdFansLagos',
 'Tricia McA @TriciaUtd',
 'Claire J Cheeseman @cjcheesecake',
 'T-Shirts world @TShirtsworld1',
 'Nagalingam @nagalingam15',
 'DevilsEmpire2020 @DevilsInc20',
 'Steven burton @stevenb_man_utd',
 'Robin MUFC @RobinSo87233182',
 '•• @Gen_Schonky',
 'Varadarajan @varadarajan1',
 'The Red Devils @TheNewRedDevils',
 'Paul @P7_Mufc',
 'Jas Rai @Jas_Rai_MUFC',
 'Bob @ManUtdMMXX',
 'BrunoMagnifico @Joanne02261171',
 'Steve farrell @fazzerfootball',
 'YesterdaysStars @YesterdaysStars',
 'Nicole! 2.0 @mademetoxic',
 '#GLAZERSOUT @Faiskhan99',
 '2019 We hit more Boundaries than NZ @BackOnYourTL',
 'branielson @branielson9',
 'Sagheer Osman @sagheerosman',
 'United Focus @united_focus_',
 'Barry @barry007j',
 'The United Focus @theunitedfocus',
 'JC @JC69mufc',
 'Alieng @Alieng11211246',
 'Tom Rooney @_TR69',
 'Prasath Ganesh @prasath_ganes',
 'D.D @diligentdalot',
 'Denver Reds @DenverRedsMUSC',
 'Pitbull @PITBULLMUFC1989',
 'Andrew @andrewbateman_',
 'Mike @mike_gilmore01',
 'Red Devils Extra @RedDevilsExtra',
 'Aditya Suresh kumar @AdityaSureshK',
 'smiler @Peter05885943',
 'All For United @allforunited',
 'Boring JamesAnderson @boringjimmy613',
 'MVG @MUtdDub',
 'Trisha @LushTrisha80',
 'shell @michellebrad196',
 'Gary McKenzie @GmMacca50',
 'Shone #MUFC @ShoneMUFC',
 'Kelvinunited @UnitedKelvin']

# %%
tw_friends=['Mahendran Kumarapandian @https://www.facebook.com/mkpandian',
 'Naveen Raam @https://www.facebook.com/naveen.raam.3',
 'Herbert Appadurai Joseph @https://www.facebook.com/jh.appadurai',
 'Jitesh PK @https://www.facebook.com/jitesh.superking',
 'Raja Raman @https://www.facebook.com/rajaramansi',
 'Sakthi Vel @https://www.facebook.com/profile.php?id=100000623826538',
 'Rahul Yesodharan @https://www.facebook.com/rahul.yeshodaran',
 'Thanu Shankar Raja @https://www.facebook.com/thanu.shankarraja',
 'தினேஷ் பீமா ராவ் @https://www.facebook.com/dinesh.kittu.3',
 'Santhosh @https://www.facebook.com/santhosh.sh.56',
 'Balaji KS @https://www.facebook.com/balag.red',
 'Senthil Velan @https://www.facebook.com/senthil.velan.921',
 'Subaraj Ditoo Raj @https://www.facebook.com/akash.here',
 'Vinayak Muruganantham @https://www.facebook.com/Muthuvinayagam37',
 'Jefery Junior Jeferyjunior @https://www.facebook.com/jeferyt',
 'Nethaji Natee @https://www.facebook.com/nethaji.netha.37',
 'Yogesh W Rajan @https://www.facebook.com/profile.php?id=100002962871977',
 'Hagin John Nadar @https://www.facebook.com/hagin.john.5',
 'MaKesh Ryan @https://www.facebook.com/makesh.aero',
 'Ancy Santhiapitchai @https://www.facebook.com/ancy.santhiapitchai',
 'Àji Sh @https://www.facebook.com/ajish.dhas.1',
 'Vicky Vicky @https://www.facebook.com/vicky.vikcy1',
 'Anand Smart @https://www.facebook.com/anand.anda.92',
 'Последний Шелл Электрон @https://www.facebook.com/uzzalhossain.uzzalkashipur',
 'Ķăvįñ Řąm @https://www.facebook.com/kavin.ram.37',
 'Saad Emaan @https://www.facebook.com/rais.saad.9',
 'Mohammed Kalz @https://www.facebook.com/mahmd.kalz',
 'Chandru Spd @https://www.facebook.com/chandru.king.39',
 'Nopri @https://www.facebook.com/noprirevan',
 'Srinivasan Muralidharan @https://www.facebook.com/msrinivasan777',
 'Tom Rae @https://www.facebook.com/tom.rae.359',
 'Magga Chetty @https://www.facebook.com/profile.php?id=100004494435078',
 'Jilla Jagan @https://www.facebook.com/profile.php?id=100004604088822',
 'Dhana Laxmi @https://www.facebook.com/profile.php?id=100004632197226',
 'Manjunadhan Punk G @https://www.facebook.com/manjunadhanpunk.g',
 'Siruthai Siva @https://www.facebook.com/profile.php?id=100005227426655',
 'Nataraj Srinivasan @https://www.facebook.com/rajesh.raina.9465',
 'Ñã Áp Żź @https://www.facebook.com/profile.php?id=100005497967259',
 'Pradesh Prathi @https://www.facebook.com/pradesh.naveen',
 'Gowtham Ravi @https://www.facebook.com/GaUtIrAvI97',
 'Dinesh Madakasira @https://www.facebook.com/madakasiradinesh',
 'Mohammad Imran Mian @https://www.facebook.com/profile.php?id=100005756770556',
 'Biju @https://www.facebook.com/biju.biju.9847867',
 'Ajith J @https://www.facebook.com/ajithstilltocome',
 'Naran Rio @https://www.facebook.com/naran.thanu.9',
 'வணக்கம் வள்ளியூர் @https://www.facebook.com/vanakkamvallioor',
 'Thamizharasan Balasubramanian @https://www.facebook.com/tamilarasan.1234567',
 'Vijay Joel @https://www.facebook.com/vijay.joel.33',
 'N. Kumaresan @https://www.facebook.com/kumaresankumar.n.5',
 'Raju Rajadurai @https://www.facebook.com/raju.rajadurai.1',
 'SN Raj Yadav @https://www.facebook.com/sakthi.sing.5',
 'Prabu R @https://www.facebook.com/profile.php?id=100006826486889',
 'Sri Iyer @https://www.facebook.com/sri.ra.182',
 'நாஞ்சில் ராஜா @https://www.facebook.com/raja.hindhumunnani.ngl',
 'Sâthÿãm Ji @https://www.facebook.com/profile.php?id=100007021455812',
 'Mustafaa Ramdaan @https://www.facebook.com/profile.php?id=100007039669455',
 'Abi Karthick @https://www.facebook.com/abi.sree.581',
 'Gān Esh JoKıee @https://www.facebook.com/ganesh.jo.92',
 'Allen Cutizz @https://www.facebook.com/allen.melaperuvilai',
 'Radha Shree @https://www.facebook.com/radha.shree.7161',
 'Arun Vijay @https://www.facebook.com/jilla.guru.963',
 'Sélvå D Çřæzý Bôý @https://www.facebook.com/kannan.venkat.503',
 'AS RF @https://www.facebook.com/asrf838',
 'Sabeena Sabi @https://www.facebook.com/sabeena.sabi.524',
 'Socialwelfare Peoplesparty @https://www.facebook.com/socialwelfare.peoplesparty',
 'Shijo Shijo @https://www.facebook.com/shijo.shijo.10441',
 'Farzana Begum @https://www.facebook.com/farzana.begum.712',
 'Héßroñ Marley @https://www.facebook.com/profile.php?id=100008123293681',
 'A.R. Architects @https://www.facebook.com/profile.php?id=100008199998597',
 'VK Raj @https://www.facebook.com/profile.php?id=100008512080047',
 'Surya Smith @https://www.facebook.com/profile.php?id=100008519857580',
 'Nuwagira Simon @https://www.facebook.com/nuwagira.simon.56',
 'Kaviyarasu @https://www.facebook.com/Kaviyarasu.Dir',
 'Shiva Sundaram @https://www.facebook.com/profile.php?id=100008636682630',
 'Vicky Cool @https://www.facebook.com/profile.php?id=100008681492166',
 'Amal Roshan @https://www.facebook.com/profile.php?id=100008819477749',
 'Saravana Victor @https://www.facebook.com/saravana.victor',
 'Abdulrazack Abdulrazack @https://www.facebook.com/abdulrazack.abdulrazack.90',
 'Ravi @https://www.facebook.com/profile.php?id=100009186180385',
 'Poungoti Siva Krishna Chowdary @https://www.facebook.com/profile.php?id=100009238608213',
 'Vicky Ak @https://www.facebook.com/profile.php?id=100009417079813',
 'Shadrack @https://www.facebook.com/profile.php?id=100009436054284',
 'Śandy Kanwar @https://www.facebook.com/sandy.kanwar.59',
 'Vinayak Lakshman YR @https://www.facebook.com/lakshmanan.kumar.355',
 'Vivegam Aravindh Kumar @https://www.facebook.com/aravindh.kumar.58958343',
 'அவந்திகா விழுப்புரம் @https://www.facebook.com/profile.php?id=100009916051818',
 'Sam Fredrick Josiah @https://www.facebook.com/sam.fredrick.710',
 'Nagalingam Nlp @https://www.facebook.com/profile.php?id=100009994150333',
 'Bĕñňý Îmmåñ @https://www.facebook.com/aginesh.agi.92',
 'Ashraf Ajmal @https://www.facebook.com/ashraf.ajmal.39',
 'Lovely Hari @https://www.facebook.com/monster.hari.547',
 'Nicole Brown @https://www.facebook.com/profile.php?id=100010723846422',
 'Ali Sher @https://www.facebook.com/profile.php?id=100010976673590',
 'Mannan Sk @https://www.facebook.com/mannan.sk.5851',
 'Sathish Kumar S @https://www.facebook.com/profile.php?id=100011101027901',
 'William Edward @https://www.facebook.com/adaikala.raj.946']

# %%
import hmni
matcher=hmni.Matcher(model='latin')

def fuzzy_name_matching(uname1,uname2):
    '''get 2 user profile names and 
    return 1 if the names match or 0'''
    match=matcher.similarity(uname1,uname2,surname_first='False',threshold=0.9,prob=False)
    return match
# Out:
# /home/vagrant/.local/lib/python3.6/site-packages/sklearn/base.py:334: UserWarning: Trying to unpickle estimator MaxAbsScaler from version 0.23.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/vagrant/.local/lib/python3.6/site-packages/sklearn/base.py:334: UserWarning: Trying to unpickle estimator MinMaxScaler from version 0.23.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/vagrant/.local/lib/python3.6/site-packages/sklearn/base.py:334: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.23.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...

# %%
for fb in fb_friends:
    fb=fb.split('@')[0].strip()
    for tw in tw_friends:
        tw=tw.split('@')[0].strip()
        match=fuzzy_name_matching(fb,tw)
        if match==1:
            print(f'Match found : {fb} - {tw}')
# Out:
# Match found : Mark - Héßroñ Marley
# Match found : Martin - Héßroñ Marley
# Match found : 𝙎𝙧𝙞 - Nataraj Srinivasan
# Match found : Rajesh - Thanu Shankar Raja
# Match found : Rajesh - Yogesh W Rajan
# Match found : Mani - Mohammad Imran Mian
# Match found : Mani - Bĕñňý Îmmåñ
# Match found : Raja - Subaraj Ditoo Raj
# Match found : Raja - Yogesh W Rajan
# Match found : Raja - நாஞ்சில் ராஜா
# Match found : Raja - VK Raj
# Match found : Sharon - Shadrack
# Match found : SHEM SHADY - Shadrack
# Match found : Mark - Héßroñ Marley
# Match found : Jas Rai - Ravi
# Match found : shell - Ali Sher

# %%
from fuzzywuzzy import fuzz 
for fb in fb_friends:
    fb=fb.split('@')[0].strip()
    for tw in tw_friends:
        tw=tw.split('@')[0].strip()
        match=fuzz.WRatio(fb,tw)
        #88 for friends match , 90 for user_name match
        if match>88:
            print(f'Match found {match}: {fb} - {tw}')
# Out:
# Match found 90: Tom - Tom Rae
# Match found 90: Ryan - MaKesh Ryan
# Match found 90: William - William Edward
# Match found 90: Mani - Thamizharasan Balasubramanian
# Match found 90: F - AS RF
# Match found 90: Raja - Raja Raman
# Match found 90: Raja - Thanu Shankar Raja
# Match found 90: Raja - Yogesh W Rajan
# Match found 90: Raja - Raju Rajadurai
# Match found 90: Ash - Ashraf Ajmal
# Match found 90: K - VK Raj
# Match found 90: K - Vicky Ak
# Match found 90: K - Shadrack
# Match found 95: Nagalingam - Nagalingam Nlp
